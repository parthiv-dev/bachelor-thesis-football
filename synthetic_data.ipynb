# %%
# Imports

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import os
import datetime as dt

# %%
df = pd.DataFrame()

# Create synthetic data for 4 columns (of size 10) with mean 10 and std 1,2,4,3

std = [1, 2, 4, 3]

for i in range(4):
    df[i] = np.random.normal(10, std[i], 10)

df
# Out:
#            0          1          2          3
# 0  10.481327   9.634003  15.861548  10.339596
# 1  11.014886  10.302458   2.018093   9.909827
# 2  10.554595  12.413266   5.811413  13.869376
# 3   9.837042   8.559738   7.841703   9.314267
# 4   9.551934  11.965799   9.041155   9.145161
# 5   9.288476  14.180913  14.110211   5.314859
# 6  10.983787   8.790830   8.693193  10.785948
# 7  10.411194   9.224095  15.040662   1.089537
# 8   9.444552  12.331707  14.194794  12.855494
# 9   9.285225   8.024261   5.423079   4.193688

# %%
# Plot data using matplotlib with each row as a line
plt.figure(figsize=(10, 5))
plt.plot(df.T, marker='o')
plt.title('Synthetic players')
plt.xlabel('Performance Metric')
plt.ylabel('Value')
plt.grid(True)
plt.show()

# %%
# Save df as csv file with name of current file and current date and time
pathname = os.path.basename(__file__)
current_time = dt.datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"data_{pathname}_{current_time}.csv"
df.to_csv(data_output/csv_filename, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Save df as csv file with name of current file and current date and time
# ----> 2 pathname = os.path.basename(__file__)
#       3 current_time = dt.datetime.now().strftime("%Y%m%d_%H%M%S")
#       4 csv_filename = f"data_{pathname}_{current_time}.csv"
#
# NameError: name '__file__' is not defined
